# %% [markdown]
# ### 大规模数据更新
#
# 注意：大规模访问可能导致被封，要注意

# %%
import akshare as ak

# 企业商品价格指数
macro_china_qyspjg_df = ak.macro_china_qyspjg()
macro_china_qyspjg_df.to_csv("data/macro_china_qyspjg_df.csv", index=False, encoding="utf-8-sig")

# 外商直接投资数据
macro_china_fdi_df = ak.macro_china_fdi()
macro_china_fdi_df.to_csv("data/macro_china_fdi_df.csv", index=False, encoding="utf-8-sig")

# 社会融资规模增量
macro_china_shrzgm_df = ak.macro_china_shrzgm()
macro_china_shrzgm_df.to_csv("data/macro_china_shrzgm_df.csv", index=False, encoding="utf-8-sig")

# 城镇调查失业率
macro_china_urban_unemployment_df = ak.macro_china_urban_unemployment()
macro_china_urban_unemployment_df.to_csv("data/macro_china_urban_unemployment_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-国民经济运行状况-经济状况-中国GDP年率报告
macro_china_gdp_yearly_df = ak.macro_china_gdp_yearly()
macro_china_gdp_yearly_df.to_csv("data/macro_china_gdp_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-国民经济运行状况-物价水平-中国CPI年率报告
macro_china_cpi_yearly_df = ak.macro_china_cpi_yearly()
macro_china_cpi_yearly_df.to_csv("data/macro_china_cpi_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-国民经济运行状况-物价水平-中国CPI月率报告
macro_china_cpi_monthly_df = ak.macro_china_cpi_monthly()
macro_china_cpi_monthly_df.to_csv("data/macro_china_cpi_monthly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-国民经济运行状况-物价水平-中国PPI年率报告
macro_china_ppi_yearly_df = ak.macro_china_ppi_yearly()
macro_china_ppi_yearly_df.to_csv("data/macro_china_ppi_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-贸易状况-以美元计算出口年率报告
macro_china_exports_yoy_df = ak.macro_china_exports_yoy()
macro_china_exports_yoy_df.to_csv("data/macro_china_exports_yoy_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-贸易状况-以美元计算进口年率
macro_china_imports_yoy_df = ak.macro_china_imports_yoy()
macro_china_imports_yoy_df.to_csv("data/macro_china_imports_yoy_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-贸易状况-以美元计算贸易帐(亿美元)
macro_china_trade_balance_df = ak.macro_china_trade_balance()
macro_china_trade_balance_df.to_csv("data/macro_china_trade_balance_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-产业指标-规模以上工业增加值年率
macro_china_industrial_production_yoy_df = ak.macro_china_industrial_production_yoy()
macro_china_industrial_production_yoy_df.to_csv("data/macro_china_industrial_production_yoy_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-产业指标-官方制造业PMI
macro_china_pmi_yearly_df = ak.macro_china_pmi_yearly()
macro_china_pmi_yearly_df.to_csv("data/macro_china_pmi_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-产业指标-财新制造业PMI终值
macro_china_cx_pmi_yearly_df = ak.macro_china_cx_pmi_yearly()
macro_china_cx_pmi_yearly_df.to_csv("data/macro_china_cx_pmi_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-产业指标-财新服务业PMI
macro_china_cx_services_pmi_yearly_df = ak.macro_china_cx_services_pmi_yearly()
macro_china_cx_services_pmi_yearly_df.to_csv("data/macro_china_cx_services_pmi_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-产业指标-中国官方非制造业PMI
macro_china_non_man_pmi_df = ak.macro_china_non_man_pmi()
macro_china_non_man_pmi_df.to_csv("data/macro_china_non_man_pmi_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-金融指标-外汇储备(亿美元)
macro_china_fx_reserves_yearly_df = ak.macro_china_fx_reserves_yearly()
macro_china_fx_reserves_yearly_df.to_csv("data/macro_china_fx_reserves_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-金融指标-M2货币供应年率
macro_china_m2_yearly_df = ak.macro_china_m2_yearly()
macro_china_m2_yearly_df.to_csv("data/macro_china_m2_yearly_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-金融指标-上海银行业同业拆借报告
macro_china_shibor_all_df = ak.macro_china_shibor_all()
macro_china_shibor_all_df.to_csv("data/macro_china_shibor_all_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-金融指标-人民币香港银行同业拆息
macro_china_hk_market_info_df = ak.macro_china_hk_market_info()
macro_china_hk_market_info_df.to_csv("data/macro_china_hk_market_info_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-其他-中国日度沿海六大电库存数据
macro_china_daily_energy_df = ak.macro_china_daily_energy()
macro_china_daily_energy_df.to_csv("data/macro_china_daily_energy_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-其他-中国人民币汇率中间价报告
macro_china_rmb_df = ak.macro_china_rmb()
macro_china_rmb_df.to_csv("data/macro_china_rmb_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-其他-深圳融资融券报告
macro_china_market_margin_sz_df = ak.macro_china_market_margin_sz()
macro_china_market_margin_sz_df.to_csv("data/macro_china_market_margin_sz_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-其他-上海融资融券报告
macro_china_market_margin_sh_df = ak.macro_china_market_margin_sh()
macro_china_market_margin_sh_df.to_csv("data/macro_china_market_margin_sh_df.csv", index=False, encoding="utf-8-sig")

# 金十数据中心-经济指标-中国-其他-上海黄金交易所报告
macro_china_au_report_df = ak.macro_china_au_report()
macro_china_au_report_df.to_csv("data/macro_china_au_report_df.csv", index=False, encoding="utf-8-sig")

# 中国-新房价指数
macro_china_new_house_price_df = ak.macro_china_new_house_price()
macro_china_new_house_price_df.to_csv("data/macro_china_new_house_price_df.csv", index=False, encoding="utf-8-sig")

# 中国-企业景气及企业家信心指数
macro_china_enterprise_boom_index_df = ak.macro_china_enterprise_boom_index()
macro_china_enterprise_boom_index_df.to_csv("data/macro_china_enterprise_boom_index_df.csv", index=False, encoding="utf-8-sig")

# 中国-全国税收收入
macro_china_national_tax_receipts_df = ak.macro_china_national_tax_receipts()
macro_china_national_tax_receipts_df.to_csv("data/macro_china_national_tax_receipts_df.csv", index=False, encoding="utf-8-sig")

# 中国-新增信贷数据
macro_china_new_financial_credit_df = ak.macro_china_new_financial_credit()
macro_china_new_financial_credit_df.to_csv("data/macro_china_new_financial_credit_df.csv", index=False, encoding="utf-8-sig")

# 中国-外汇和黄金储备
macro_china_fx_gold_df = ak.macro_china_fx_gold()
macro_china_fx_gold_df.to_csv("data/macro_china_fx_gold_df.csv", index=False, encoding="utf-8-sig")

macro_china_stock_market_cap_df = ak.macro_china_stock_market_cap()
macro_china_stock_market_cap_df.to_csv("data/macro_china_stock_market_cap_df.csv", index=False, encoding="utf-8-sig")

macro_china_money_supply_df = ak.macro_china_money_supply()
macro_china_money_supply_df.to_csv("data/macro_china_money_supply_df.csv", index=False, encoding="utf-8-sig")

macro_china_cpi_df = ak.macro_china_cpi()
macro_china_cpi_df.to_csv("data/macro_china_cpi_df.csv", index=False, encoding="utf-8-sig")

macro_china_gdp_df = ak.macro_china_gdp()
macro_china_gdp_df.to_csv("data/macro_china_gdp_df.csv", index=False, encoding="utf-8-sig")

macro_china_ppi_df = ak.macro_china_ppi()
macro_china_ppi_df.to_csv("data/macro_china_ppi_df.csv", index=False, encoding="utf-8-sig")

macro_china_pmi_df = ak.macro_china_pmi()
macro_china_pmi_df.to_csv("data/macro_china_pmi_df.csv", index=False, encoding="utf-8-sig")

macro_china_gdzctz_df = ak.macro_china_gdzctz()
macro_china_gdzctz_df.to_csv("data/macro_china_gdzctz_df.csv", index=False, encoding="utf-8-sig")

macro_china_hgjck_df = ak.macro_china_hgjck()
macro_china_hgjck_df.to_csv("data/macro_china_hgjck_df.csv", index=False, encoding="utf-8-sig")

macro_china_czsr_df = ak.macro_china_czsr()
macro_china_czsr_df.to_csv("data/macro_china_czsr_df.csv", index=False, encoding="utf-8-sig")

macro_china_whxd_df = ak.macro_china_whxd()
macro_china_whxd_df.to_csv("data/macro_china_whxd_df.csv", index=False, encoding="utf-8-sig")

macro_china_wbck_df = ak.macro_china_wbck()
macro_china_wbck_df.to_csv("data/macro_china_wbck_df.csv", index=False, encoding="utf-8-sig")

macro_china_xfzxx_df = ak.macro_china_xfzxx()
macro_china_xfzxx_df.to_csv("data/macro_china_xfzxx_df.csv", index=False, encoding="utf-8-sig")

macro_china_gyzjz_df = ak.macro_china_gyzjz()
macro_china_gyzjz_df.to_csv("data/macro_china_gyzjz_df.csv", index=False, encoding="utf-8-sig")

macro_china_reserve_requirement_ratio_df = ak.macro_china_reserve_requirement_ratio()
macro_china_reserve_requirement_ratio_df.to_csv("data/macro_china_reserve_requirement_ratio_df.csv", index=False, encoding="utf-8-sig")

macro_china_consumer_goods_retail_df = ak.macro_china_consumer_goods_retail()
macro_china_consumer_goods_retail_df.to_csv("data/macro_china_consumer_goods_retail_df.csv", index=False, encoding="utf-8-sig")

macro_china_society_electricity_df = ak.macro_china_society_electricity()
macro_china_society_electricity_df.to_csv("data/macro_china_society_electricity_df.csv", index=False, encoding="utf-8-sig")

# macro_china_society_traffic_volume_df = ak.macro_china_society_traffic_volume()
# macro_china_society_traffic_volume_df.to_csv("data/macro_china_society_traffic_volume_df.csv", index=False, encoding="utf-8-sig")

# macro_china_postal_telecommunicational_df = ak.macro_china_postal_telecommunicational()
# macro_china_postal_telecommunicational_df.to_csv("data/macro_china_postal_telecommunicational_df.csv", index=False, encoding="utf-8-sig")

# macro_china_international_tourism_fx_df = ak.macro_china_international_tourism_fx()
# macro_china_international_tourism_fx_df.to_csv("data/macro_china_international_tourism_fx_df.csv", index=False, encoding="utf-8-sig")

# macro_china_passenger_load_factor_df = ak.macro_china_passenger_load_factor()
# macro_china_passenger_load_factor_df.to_csv("data/macro_china_passenger_load_factor_df.csv", index=False, encoding="utf-8-sig")

macro_china_freight_index_df = ak.macro_china_freight_index()
macro_china_freight_index_df.to_csv("data/macro_china_freight_index_df.csv", index=False, encoding="utf-8-sig")

# macro_china_central_bank_balance_df = ak.macro_china_central_bank_balance()
# macro_china_central_bank_balance_df.to_csv("data/macro_china_central_bank_balance_df.csv", index=False, encoding="utf-8-sig")

# macro_china_insurance_df = ak.macro_china_insurance()
# macro_china_insurance_df.to_csv("data/macro_china_insurance_df.csv", index=False, encoding="utf-8-sig")

# macro_china_supply_of_money_df = ak.macro_china_supply_of_money()
# macro_china_supply_of_money_df.to_csv("data/macro_china_supply_of_money_df.csv", index=False, encoding="utf-8-sig")

# macro_china_foreign_exchange_gold_df = ak.macro_china_foreign_exchange_gold()
# macro_china_foreign_exchange_gold_df.to_csv("data/macro_china_foreign_exchange_gold_df.csv", index=False, encoding="utf-8-sig")

# macro_china_retail_price_index_df = ak.macro_china_retail_price_index()
# macro_china_retail_price_index_df.to_csv("data/macro_china_retail_price_index_df.csv", index=False, encoding="utf-8-sig")

# macro_china_real_estate_df = ak.macro_china_real_estate()
# macro_china_real_estate_df.to_csv("data/macro_china_real_estate_df.csv", index=False, encoding="utf-8-sig")

# macro_shipping_bci_df = ak.macro_shipping_bci()
# macro_shipping_bci_df.to_csv("data/macro_shipping_bci_df.csv", index=False, encoding="utf-8-sig")

# macro_shipping_bdi_df = ak.macro_shipping_bdi()
# macro_shipping_bdi_df.to_csv("data/macro_shipping_bdi_df.csv", index=False, encoding="utf-8-sig")

# macro_shipping_bpi_df = ak.macro_shipping_bpi()
# macro_shipping_bpi_df.to_csv("data/macro_shipping_bpi_df.csv", index=False, encoding="utf-8-sig")

# macro_shipping_bcti_df = ak.macro_shipping_bcti()
# macro_shipping_bcti_df.to_csv("data/macro_shipping_bcti_df.csv", index=False, encoding="utf-8-sig")
